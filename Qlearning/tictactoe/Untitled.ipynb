# %%
import game
import numpy as np
import copy

env = game.env()

old_agent = game.agent()

# %%
for i in range(1):
    new_agent = copy.deepcopy(old_agent)

    for episode in range(10000000):
        if (episode + 1) % 10000 == 0:
            print('%d episodes played' %(episode+1))
        step = 0
        done = False
        player = 1 # 1 : new, -1 : old

        agent = [new_agent, old_agent]
        state = env.reset()     

        action = agent[step%2].get_action(state)
        new_state, reward, done = env.step(action, player)

        step += 1
        player *= -1

        bef_action = action
        bef_state = state
        bef_reward = reward

        state = new_state

        while not done:
            action = agent[step%2].get_action(player*state)
            new_state, reward, done = env.step(action, player)       

            agent[(step+1)%2].learn(bef_state, bef_action, new_state, bef_reward-reward)
            if done or step==8:
                agent[step%2].learn(state, action, new_state, reward)
                break

            bef_action = action
            bef_state = state
            bef_reward = reward

            state = new_state

            step += 1
            player *= -1
# Out:
# 10000 episodes played
# 20000 episodes played
# 30000 episodes played
# 40000 episodes played
# 50000 episodes played
# 60000 episodes played
# 70000 episodes played
# 80000 episodes played
# 90000 episodes played
# 100000 episodes played
# 110000 episodes played
# 120000 episodes played
# 130000 episodes played
# 140000 episodes played
# 150000 episodes played
# 160000 episodes played
# 170000 episodes played
# 180000 episodes played
# 190000 episodes played
# 200000 episodes played
# 210000 episodes played
# 220000 episodes played
# 230000 episodes played
# 240000 episodes played
# 250000 episodes played
# 260000 episodes played
# 270000 episodes played
# 280000 episodes played
# 290000 episodes played
# 300000 episodes played
# 310000 episodes played
# 320000 episodes played
# 330000 episodes played
# 340000 episodes played
# 350000 episodes played
# 360000 episodes played
# 370000 episodes played
# 380000 episodes played
# 390000 episodes played
# 400000 episodes played
# 410000 episodes played
# 420000 episodes played
# 430000 episodes played
# 440000 episodes played
# 450000 episodes played
# 460000 episodes played
# 470000 episodes played
# 480000 episodes played
# 490000 episodes played
# 500000 episodes played
# 510000 episodes played
# 520000 episodes played
# 530000 episodes played
# 540000 episodes played
# 550000 episodes played
# 560000 episodes played
# 570000 episodes played
# 580000 episodes played
# 590000 episodes played
# 600000 episodes played
# 610000 episodes played
# 620000 episodes played
# 630000 episodes played
# 640000 episodes played
# 650000 episodes played
# 660000 episodes played
# 670000 episodes played
# 680000 episodes played
# 690000 episodes played
# 700000 episodes played
# 710000 episodes played
# 720000 episodes played
# 730000 episodes played
# 740000 episodes played
# 750000 episodes played
# 760000 episodes played
# 770000 episodes played
# 780000 episodes played
# 790000 episodes played
# 800000 episodes played
# 810000 episodes played
# 820000 episodes played
# 830000 episodes played
# 840000 episodes played
# 850000 episodes played
# 860000 episodes played
# 870000 episodes played
# 880000 episodes played
# 890000 episodes played
# 2100000 episodes played
# 2110000 episodes played
# 2120000 episodes played
# 2130000 episodes played
# 2140000 episodes played
# 2150000 episodes played
# 2160000 episodes played
# 2170000 episodes played
# 2180000 episodes played
# 2190000 episodes played
# 2200000 episodes played
# 2210000 episodes played
# 2220000 episodes played
# 2230000 episodes played
# 2240000 episodes played
# 2250000 episodes played
# 2260000 episodes played
# 2270000 episodes played
# 2280000 episodes played
# 2290000 episodes played
# 2300000 episodes played
# 2310000 episodes played
# 2320000 episodes played
# 2330000 episodes played
# 2340000 episodes played
# 2350000 episodes played
# 2360000 episodes played
# 2370000 episodes played
# 2380000 episodes played
# 2390000 episodes played
# 2400000 episodes played
# 2410000 episodes played
# 2420000 episodes played
# 2430000 episodes played
# 2440000 episodes played
# 2450000 episodes played
# 2460000 episodes played
# 2470000 episodes played
# 2480000 episodes played
# 2490000 episodes played
# 2500000 episodes played
# 2510000 episodes played
# 2520000 episodes played
# 2530000 episodes played
# 2540000 episodes played
# 2550000 episodes played
# 2560000 episodes played
# 2570000 episodes played
# 2580000 episodes played
# 2590000 episodes played
# 2600000 episodes played
# 2610000 episodes played
# 2620000 episodes played
# 2630000 episodes played
# 2640000 episodes played
# 2650000 episodes played
# 2660000 episodes played
# 2670000 episodes played
# 2680000 episodes played
# 2690000 episodes played
# 2700000 episodes played
# 2710000 episodes played
# 2720000 episodes played
# 2730000 episodes played
# 2740000 episodes played
# 2750000 episodes played
# 2760000 episodes played
# 2770000 episodes played
# 2780000 episodes played
# 2790000 episodes played
# 2800000 episodes played
# 2810000 episodes played
# 2820000 episodes played
# 2830000 episodes played
# 2840000 episodes played
# 2850000 episodes played
# 2860000 episodes played
# 2870000 episodes played
# 2880000 episodes played
# 2890000 episodes played
# 2900000 episodes played
# 2910000 episodes played
# 2920000 episodes played
# 2930000 episodes played
# 2940000 episodes played

# %%
def actcompress(i, j):
    return 3*i+j

print(old_agent.qtable.shape)

# %%
state = env.reset()
agent = old_agent
step = 0
done = False
player = 1

while not done:
    print(step)

    if step % 2==0: 
        action = agent.get_action(state)
    else:
        acti, actj = input().split()
        action = actcompress(int(acti), int(actj))

    new_state, reward, done = env.step(action, player)       
    env.render()

    if done or step==8:
        break

    state = new_state

    step += 1
    player *= -1
# Out:
# 0
# ***
# ***
# **O
#
# 1
# 1 1
# ***
# *X*
# **O
#
# 2
# ***
# OX*
# **O
#
# 3
# 1 2
# ***
# OXX
# **O
#
# 4
# O**
# OXX
# **O
#
# 5
# 2 0
# O**
# OXX
# X*O
#
# 6
# OO*
# OXX
# X*O
#
# 7
# 0 2
# OOX
# OXX
# X*O
